# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('Dry_Bean_Dataset.csv')

# %%
df
# Out:
#         Area  Perimeter  MajorAxisLength  MinorAxisLength  AspectRation  \
# 0      28395    610.291       208.178117       173.888747      1.197191
# 1      28734    638.018       200.524796       182.734419      1.097356
# 2      29380    624.110       212.826130       175.931143      1.209713
# 3      30008    645.884       210.557999       182.516516      1.153638
# 4      30140    620.134       201.847882       190.279279      1.060798
# ...      ...        ...              ...              ...           ...
# 13606  42097    759.696       288.721612       185.944705      1.552728
# 13607  42101    757.499       281.576392       190.713136      1.476439
# 13608  42139    759.321       281.539928       191.187979      1.472582
# 13609  42147    763.779       283.382636       190.275731      1.489326
# 13610  42159    772.237       295.142741       182.204716      1.619841
#
#        Eccentricity  ConvexArea  EquivDiameter    Extent  Solidity  roundness  \
# ...

# %%
Y=df['Class']

# %%
Y
# Out:
# 0           SEKER
# 1           SEKER
# 2           SEKER
# 3           SEKER
# 4           SEKER
#            ...
# 13606    DERMASON
# 13607    DERMASON
# 13608    DERMASON
# 13609    DERMASON
# 13610    DERMASON
# Name: Class, Length: 13611, dtype: object

# %%
X = df.drop('Class',axis=1)
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.2,random_state=0)

# %%
x.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 x.shape
#
# NameError: name 'x' is not defined

# %%
from sklearn.decomposition import PCA

n_components = 2
pca = PCA(n_components=2)
pca.fit(x)
x_pca = pca.transform(x)

df_pca1 = pd.DataFrame(x_pca,columns=['PC{}'.format(i+1) for i in range(n_components)])
print(df_pca1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[18], line 5
#       3 n_components = 2
#       4 pca = PCA(n_components=2)
# ----> 5 pca.fit(x)
#       6 x_pca = pca.transform(x)
#       8 df_pca1 = pd.DataFrame(x_pca,columns=['PC{}'.format(i+1) for i in range(n_components)])
#
# NameError: name 'x' is not defined

# %%
df_pca1.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 df_pca1.shape
#
# NameError: name 'df_pca1' is not defined

# %%
from sklearn.cluster import KMeans

# %%
for i in range(1,11):
    kmean = KMeans(n_clusters = i, init = 'k-means++', n_init = 'auto', random_state = 78).fit(df_pca , y_train)
    wcss_list.append(kmean.inertia_)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 for i in range(1,11):
# ----> 2     kmean = KMeans(n_clusters = i, init = 'k-means++', n_init = 'auto', random_state = 78).fit(df_pca , y_train)
#       3     wcss_list.append(kmean.inertia_)
#
# NameError: name 'df_pca' is not defined

# %%
kmeans = KMeans(n_clusters=5, init='k-means++', random_state=42)
y_predict= kmeans.fit_predict(x_pca)
# Out:
# C:\Users\lokes\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1412: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   super()._check_params_vs_input(X, default_n_init=10)

# %%
cluster_centers = kmeans.cluster_centers_
cluster_labels = kmeans.labels_

plt.scatter(x_pca[:,0],x_pca[:,1], c=cluster_labels, cmap='viridis', s=50, alpha=0.5)
plt.scatter(cluster_centers[:,0], cluster_centers[:,1], c='black', s=200)
plt.title('KMeans Clustering with PCA')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.colorbar(label='Cluster')
plt.show()

# %%
import joblib

# %%
joblib.dump(kmeans,'K_means')
# Out:
# ['K_means']

# %%
kmean = KMeans(n_clusters = 7, random_state = 7, init = 'k-means++', n_init = 'auto').fit(X_train_reduced, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 kmean = KMeans(n_clusters = 7, random_state = 7, init = 'k-means++', n_init = 'auto').fit(X_train_reduced, y_train)
#
# NameError: name 'KMeans' is not defined
